# %% [markdown]
# ### 파이썬 기초 문법
# #### 1. 숫자형

# %%
a = 123
print(a)

a = -178
print(a)
# Out:
# 123
# -178

# %%
a = 1.2
print(a)

a = -3.45
print(a)
# Out:
# 1.2
# -3.45

# %%
# 4.24 * 10의 -10
a = 4.24e-10
print(a)
# Out:
# 4.24e-10

# %%
# 8진수 : 0o
# 16진수 : 0x

a = 0o177
print(a)

a = 0x8ff
print(a)
# Out:
# 127
# 2303

# %%
# +,-,*,/,//,%,**

a = 3
b = 4

print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b) # 몫만
print(a % b) # 나머지만
print(a ** b) # 제곱
# Out:
# 7
# -1
# 12
# 0.75
# 0
# 3
# 81

# %% [markdown]
# #### 2. 문자열 자료형
# - 문자, 단어 등으로 구성된 문자들의 집합
# - 큰 따옴표, 작은 따옴표, 큰 따옴표 3개 , 작은 따옴표 3개
# - 이스케이프 코드
#      - \n : enter
#      - \t : tab
#      - \\ : \ 문자

# %%
a = "Hello world"
a = 'Hello world'
a = """Life is too short, you need python"""
a = '''Life is too short, you need python'''

# %%
a = "python's"
# a = 'python's'
a
# Out:
# "python's"

# %%
multiline =  """Life is too short,\nyou need python"""
multiline
# Out:
# 'Life is too short,\nyou need python'

# %%
a = "345678"

# %%
head = "python"
tail = " is fun!!"

# 결합(연결)
head + tail
# Out:
# 'python is fun!!'

# %%
# * : 반복
"python" * 2
# Out:
# 'pythonpython'

# %%
# ===================
# My program
# ===================

print("=" * 20)
print("My program")
print("=" * 20)
# Out:
# ====================
# My program
# ====================

# %%
# len() : 길이 구하기
# 공백포함

len("Life is too short, you need python")
# Out:
# 34

# %% [markdown]
# #### 인덱싱과 슬라이싱
#  - 인덱스는 0번 부터 시작

# %%
a = "Life is too short, you need python"
print(a[33])
print(a[-1])
# Out:
# n
# n

# %%
# 슬라이싱 시 끝번호는 포함하지 않음

print(a[0:5])
print(a[0:2])
print(a[5:7])
print(a[12:17])
print(a[:])
print(a[19:-7])
print(a[19:])
print(a[:5])
# Out:
# Life
# Li
# is
# short
# Life is too short, you need python
# you need
# you need python
# Life

# %%
a ="20260714Rainy"
# 날짜와 날씨 분리
print(a[:8])
print(a[8:])

# 년,월,일
print(a[:4])
print(a[4:6])
print(a[6:8])
# Out:
# 20260714
# Rainy
# 2026
# 07
# 14

# %% [markdown]
# #### 문자열 포매팅
# - 문자열 안에 어떤 값을 삽입하는 방법
#
# | 코드 | 설명 |
# | --- | ---  |
# | `%s`  | 문자열(string) |
# | `%d`  | 정수(integer) |
# | `%c`  | 문자 1개(character) |
# | `%f`  | 부동. 소수(floating-point) |
# | `%o`  | 8진수 |
# | `%x`  | 16진수 |
# | `%%`  | % 문자 자체 |
#
# - format() 함수 사용
# - f 문자열 포매팅(파이썬 3.6버전 부터 지원)

# %%
a = "I eat %d apples" % 5
a
# Out:
# 'I eat 5 apples'

# %%
# %s => 어떤 값이든 대입 가능
# %s : 문자열 값

a  = "I eat %s apples" % "five"
a
# Out:
# 'I eat five apples'

# %%
a = "Error is %d%%" % 98
a
# Out:
# 'Error is 98%'

# %%
a = " I eat %d apples. so I was sick for %s days" %(10,"three")
a
# Out:
# ' I eat 10 apples. so I was sick for three days'

# %%
# hi 문자열 출력 시 10개인 공간 사용
# 오른쪽 정렬

print("%10s" % "hi")

# 왼쪽 정렬
print("%-10sjane" % "hi")

# 0 : 길이에 상관하지 않음
# 소수점 네 번째 자리까지만
print("%0.4f" % 3.42341234)

# 전체 길이 10개인 문자열 공간에서 오른쪽 정렬
print("%10.4f" % 3.42341234)
# Out:
#         hi
# hi        jane
# 3.4234
#     3.4234

# %%
a = "I eat {} apples".format(5)
a
# Out:
# 'I eat 5 apples'

# %%
# a = " I eat {} apples. so I was sick for {} days".format(10,"three")
a = " I eat {0} apples. so I was sick for {1} days".format(10,"three")
a
# Out:
# ' I eat 10 apples. so I was sick for three days'

# %%
name = "홍길동"
age = 30

# 첫번째 방법
print("나의 이름은 %s 이고, 나이는 %d 입니다" % (name, age))

#두번째 방법
print("나의 이름은 {} 이고, 나이는 {} 입니다".format(name, age))

# f문자열 포매팅
print(f"나의 이름은 {name} 이고, 나이는 {age} 입니다")
# Out:
# 나의 이름은 홍길동 이고, 나이는 30 입니다
# 나의 이름은 홍길동 이고, 나이는 30 입니다
# 나의 이름은 홍길동 이고, 나이는 30 입니다

# %%
name = "홍길동"
age = 30

# 첫번째 방법
print("나의 이름은 %s 이고, 나이는 %d 입니다" % (name, age))

#두번째 방법
print("나의 이름은 {} 이고, 나이는 {} 입니다".format(name, age))

# f문자열 포매팅
print(f"나의 이름은 {name} 이고, 나이는 {age} 입니다")
print(f"나의 이름은 {name} 이고, 내년에 나이는 {age+1} 입니다")
# Out:
# 나의 이름은 홍길동 이고, 나이는 30 입니다
# 나의 이름은 홍길동 이고, 나이는 30 입니다
# 나의 이름은 홍길동 이고, 나이는 30 입니다
# 나의 이름은 홍길동 이고, 내년에 나이는 31 입니다

# %% [markdown]
# #### 문자열 함수

# %%
a = "hobby"

# 문자열안에 b라는 문자의 개수 세기
print(a.count('b'))

"test".count("t")
# Out:
# 2
# 2

# %%
# b 위치 찾기
a = "python is the best choice"

a.find('b')

# 못찾으면 -1
a.find('k')
# Out:
# -1

# %%
a.index('b')

# 못찾으면 ValueError
# a.index('k')
# Out:
# 14

# %%
# join()

",".join("abcde")
# Out:
# 'a,b,c,d,e'

# %%
# 대소문자 변경

print("hi".upper())
print("Hi".lower())
print("hi".lower())
# Out:
# HI
# hi
# hi

# %%
# 공백제거
# == : 같은가?

print('hi' == ' hi ')

a = ' hi '

# 왼쪽 공백 제거
print(a.lstrip())
# 오른쪽 공백 제거
print(a.rstrip())
# 양쪽 공백 제거
print(a.strip())
print('hi' == a.strip())
print(a)
# Out:
# False
# hi
#  hi
# hi
# True
#  hi

# %%
# 문자열 변경 : replace("바뀔문자열","변경할문자열")
a = "Life is too short"
print(a.replace("Life","Your leg"))
print(a)
# Out:
# Your leg is too short
# Life is too short

# %%
# 문자열 나누기

# 공백 기준으로 문자열 분리
a.split()

b = "a,b,c,d"
b.split(",")
# Out:
# ['a', 'b', 'c', 'd']
